# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Library_Usage.csv')

# %%
df.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 3                 SENIOR               28              13
# 1                 0                  ADULT               21              10
# 2                 0                  ADULT              275             559
# 3                 0                  ADULT               73              38
# 4                 0                  ADULT              182              90
#
#         Age Range Home Library Code Home Library Definition  \
# 0  65 to 74 years                 X            Main Library
# 1  55 to 59 years                 X            Main Library
# 2  60 to 64 years                 X            Main Library
# 3  45 to 54 years                M8             Mission Bay
# 4  45 to 54 years                 X            Main Library
#
#   Circulation Active Month Circulation Active Year Notice Preference Code  \
# ...

# %%
# Dataset contains two dependent variables i.e., 'Total Checkouts' & 'Total Renewals' 
# and it tell about how many  data patron are using the library and what what are their age groups and 
# whether they are from the country or outside of the country, how many checkout and renewals were done in different
# months and years

# %%
df.tail()
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 423443                 0                  ADULT              170
# 423444                 1               JUVENILE                4
# 423445                 0                  ADULT                4
# 423446                 0                  ADULT               30
# 423447                 2            YOUNG ADULT              662
#
#         Total Renewals       Age Range Home Library Code  \
# 423443              12  45 to 54 years                 X
# 423444               0  10 to 19 years                 X
# 423445               1  25 to 34 years                 X
# 423446               4  20 to 24 years                O7
# 423447              93  10 to 19 years                A5
#
#        Home Library Definition Circulation Active Month  \
# 423443            Main Library                   August
# 423444            Main Library                    March
# ...

# %% [markdown]
# ##

# %%
df.shape
# Out:
# (423448, 15)

# %%
df.isnull().sum()
# Out:
# Patron Type Code                     0
# Patron Type Definition               0
# Total Checkouts                      0
# Total Renewals                       0
# Age Range                          215
# Home Library Code                   40
# Home Library Definition              0
# Circulation Active Month             0
# Circulation Active Year              0
# Notice Preference Code               0
# Notice Preference Definition         0
# Provided Email Address               0
# Year Patron Registered               0
# Outside of County                    0
# Supervisor District             110310
# dtype: int64

# %%
plt.figure(figsize=(15,15))
sns.countplot(x='Circulation Active Year',data=df)             
#Highesht numbers of books are circulated in the year 2016

plt.show()

# %%
age_ranges_order=['0 to 9 years','10 to 19 years','20 to 24 years','25 to 34 years',
            '35 to 44 years','45 to 54 years','55 to 59 years','60 to 64 years',
            '65 to 74 years','75 years and over','Not Defined']

# %%
plt.figure(figsize=(15,15))
sns.countplot(x='Patron Type Code',data=df)             
#Highesht numbers of books are circulated by Adults (0 = adults)

plt.show()

# %%
#plt.figure(figsize=(15,15))
sns.countplot(x='Notice Preference Definition',data=df)             
#Highesht numbers of Notices are sent through Email

plt.show()

# %%
plt.figure(figsize=(300,300))
sns.displot(df['Year Patron Registered'], kde=True)
plt.show()

#The highest number of registration was in the year 2004.

# %%
sns.countplot(x='Outside of County',data=df)             
#Most Patraeons are from the country and very less are from outside the country

plt.show()

# %%
plt.title('Age Range Destribution',fontsize=15)
sns.countplot(y='Age Range', data=df)

#Most number of patrons are from 25-34 year of age
# Out:
# <AxesSubplot:title={'center':'Age Range Destribution'}, xlabel='count', ylabel='Age Range'>

# %%
plt.figure(figsize=(5,10))
plt.title('Home Library Registration', fontsize=15)
plt.xticks(rotation=45)
sns.countplot(y='Home Library Definition', data=df)

#Main Library has the most number of books registered
# Out:
# <AxesSubplot:title={'center':'Home Library Registration'}, xlabel='count', ylabel='Home Library Definition'>

# %%
plt.figure(figsize=(16,9))

new_df = df[['Year Patron Registered','Total Checkouts','Total Renewals']]
new_df_set = new_df.set_index(['Year Patron Registered'])
sns.lineplot(data=new_df_set)

#Both total checkout and Total renewals has declined over the year
# Out:
# <AxesSubplot:xlabel='Year Patron Registered'>

# %%
df.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 3                 SENIOR               28              13
# 1                 0                  ADULT               21              10
# 2                 0                  ADULT              275             559
# 3                 0                  ADULT               73              38
# 4                 0                  ADULT              182              90
#
#         Age Range Home Library Code Home Library Definition  \
# 0  65 to 74 years                 X            Main Library
# 1  55 to 59 years                 X            Main Library
# 2  60 to 64 years                 X            Main Library
# 3  45 to 54 years                M8             Mission Bay
# 4  45 to 54 years                 X            Main Library
#
#   Circulation Active Month Circulation Active Year Notice Preference Code  \
# ...

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='Patron Type Code',y='Total Renewals',data=df)

#This shows how many renewals were done by Patrons - Patron 5(Staff) has the most number of renewal
# Out:
# <AxesSubplot:xlabel='Patron Type Code', ylabel='Total Renewals'>

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='Patron Type Code',y='Total Renewals',data=df)  
#This indicates that the mean Renewals are more for STAFF (Patron code 5 indicates staff )
# Out:
# <AxesSubplot:xlabel='Patron Type Code', ylabel='Total Renewals'>

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='Patron Type Code',y='Total Checkouts',data=df)  
#This indicates that the mean Checkouts are more for Retired Staff (Patron code 55 indicates Retired staff )
# Out:
# <AxesSubplot:xlabel='Patron Type Code', ylabel='Total Checkouts'>

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='Circulation Active Year',y='Total Checkouts',data=df)  
#This indicates that themost  mean Checkouts were done in 2016
# Out:
# <AxesSubplot:xlabel='Circulation Active Year', ylabel='Total Checkouts'>

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='Circulation Active Year',y='Total Renewals',data=df)  
#This indicates that the most mean Renewals done in 2016
# Out:
# <AxesSubplot:xlabel='Circulation Active Year', ylabel='Total Renewals'>

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='Age Range',y='Total Checkouts',data=df)  
#This indicates mean checkout was highest in age above 75 years
# Out:
# <AxesSubplot:xlabel='Age Range', ylabel='Total Checkouts'>

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='Age Range',y='Total Renewals',data=df)  
#This indicates mean renewal was highest in age between 60-64 Years
# Out:
# <AxesSubplot:xlabel='Age Range', ylabel='Total Renewals'>

# %%
plt.figure(figsize=(20, 9))

sns.barplot(x='Total Renewals',y='Patron Type Definition',data=df)  

#Total renewal for staff is highest among all and lowest is for welcome and digital access card
# Out:
# <AxesSubplot:xlabel='Total Renewals', ylabel='Patron Type Definition'>

# %%
plt.figure(figsize=(20, 9))

sns.barplot(x='Total Checkouts',y='Patron Type Definition',data=df)  

#Total Checkout for Retires staff is highest and lowest is for welcome and digital access card
# Out:
# <AxesSubplot:xlabel='Total Checkouts', ylabel='Patron Type Definition'>

# %%
plt.figure(figsize=(16, 9))

sns.barplot(x=df['Circulation Active Month'], y=df['Total Checkouts'])

#July is the highest value in Total Checkouts and September is the lowest month
# Out:
# <AxesSubplot:xlabel='Circulation Active Month', ylabel='Total Checkouts'>

# %%
plt.figure(figsize=(16, 9))

sns.barplot(x=df['Circulation Active Month'], y=df['Total Renewals'])

#July is the highest value in Total Renewal and October is the lowest month.
# Out:
# <AxesSubplot:xlabel='Circulation Active Month', ylabel='Total Renewals'>

# %%
sns.regplot(x=df['Total Checkouts'], y=df['Total Renewals'])

#Total Checkouts and total renewals are densely populated
# Out:
# <AxesSubplot:xlabel='Total Checkouts', ylabel='Total Renewals'>

# %%
plt.figure(figsize=(8,8))
ax = sns.stripplot(x = "Year Patron Registered", y = "Total Checkouts", data = df, jitter=True)
ax = plt.xticks(fontsize = 12,color="steelblue", alpha=0.8, rotation = 45)
ax = plt.yticks(fontsize = 12,color="steelblue", alpha=0.8)
ax = plt.xlabel("Registration Year", fontsize = 15)
ax = plt.ylabel("Total Checkout #", fontsize = 15)
ax = plt.title("Total Checkout vs Registration Year", fontsize = 18)

#Most Checkouts were done in year 2003

# %%
plt.figure(figsize=(8,8))
ax = sns.stripplot(x = "Year Patron Registered", y = "Total Renewals", data = df, jitter=True)
ax = plt.xticks(fontsize = 12,color="steelblue", alpha=0.8, rotation = 45)
ax = plt.yticks(fontsize = 12,color="steelblue", alpha=0.8)
ax = plt.xlabel("Registration Year",fontsize = 15)
ax = plt.ylabel("Total Renewal #",fontsize = 15)
ax = plt.title("Total Renewal vs Registration Year",fontsize = 18)

#Most Renewals were done in year 2003

# %%
plt.figure(figsize=(8,8))
ax = sns.stripplot(x = "Age Range", y = "Total Renewals", data = df, jitter=True)
ax = plt.xticks(fontsize = 12,color="steelblue", alpha=0.8, rotation = 45)
ax = plt.yticks(fontsize = 12,color="steelblue", alpha=0.8)
ax = plt.xlabel("Age Range",fontsize = 15)
ax = plt.ylabel("Total Renewal #",fontsize = 15)
ax = plt.title("Total Renewal vs Age Range",fontsize = 18)

#Most renewals were done by age group 35-44 years

# %%
plt.figure(figsize=(8,8))
ax = sns.stripplot(x = "Age Range", y = "Total Checkouts", data = df, jitter=True)
ax = plt.xticks(fontsize = 12,color="steelblue", alpha=0.8, rotation = 45)
ax = plt.yticks(fontsize = 12,color="steelblue", alpha=0.8)
ax = plt.xlabel("Age Range", fontsize = 15)
ax = plt.ylabel("Total Checkout #", fontsize = 15)
ax = plt.title("Total Checkout vs Age Range", fontsize = 18)

#Most checkouts were done by age group 45-54 years

# %%
plt.figure(figsize=(8,8))
ax = sns.stripplot(x = "Patron Type Code", y = "Total Checkouts", data = df, jitter=True)
ax = plt.xticks(fontsize = 12,color="steelblue", alpha=0.8, rotation = 45)
ax = plt.yticks(fontsize = 12,color="steelblue", alpha=0.8)
ax = plt.xlabel("Patron Type Code", fontsize = 15)
ax = plt.ylabel("Total Checkout #", fontsize = 15)
ax = plt.title("Total Checkout vs Patron Type", fontsize = 18)

#Most checkouts were done by Patron type 5 (Adult)

# %%
plt.figure(figsize=(8,8))
ax = sns.stripplot(x = "Patron Type Code", y = "Total Renewals", data = df, jitter=True)
ax = plt.xticks(fontsize = 12,color="steelblue", alpha=0.8, rotation = 45)
ax = plt.yticks(fontsize = 12,color="steelblue", alpha=0.8)
ax = plt.xlabel("Patron Type Code", fontsize = 15)
ax = plt.ylabel("Total Renewals #", fontsize = 15)
ax = plt.title("Total Checkout vs Patron Type", fontsize = 18)

# Most Renewals were done by Patron type 0 (Adult)

# %%
plt.title('Age Range vs Year Patron Registerd')
sns.boxplot(y='Age Range',
              x='Year Patron Registered',
              data=df,order=age_ranges_order)

#75 and above year patron get registered before 2012
# Out:
# <AxesSubplot:title={'center':'Age Range vs Year Patron Registerd'}, xlabel='Year Patron Registered', ylabel='Age Range'>

# %%
plt.figure(figsize=(5,10))
plt.title('Registered Year distribution per Library')
sns.boxplot(y='Home Library Definition',
              x='Year Patron Registered',
              data=df)

#2011 & 2012 are the mean year for majority of the registrations
# Out:
# <AxesSubplot:title={'center':'Registered Year distribution per Library'}, xlabel='Year Patron Registered', ylabel='Home Library Definition'>

# %%
pivot = pd.pivot_table(df,
            values = ['Total Checkouts'],
            index = ['Patron Type Definition'], 
                       columns= ['Age Range'],
                       aggfunc=[np.mean], 
                       margins=True)
pivot
cmap = sns.cubehelix_palette(start = 1.5, rot = 1.5, as_cmap = True)
plt.subplots(figsize = (30, 20))
sns.heatmap(pivot,linewidths=0.2,square=True )

#Majorits of entries in the category of the patron type 
#defination and the age group have total checkouts of 250 and below

#retired staff has total checkouts of more than 1750
# Out:
# <AxesSubplot:xlabel='None-None-Age Range', ylabel='Patron Type Definition'>

# %%
pivot = pd.pivot_table(df,
            values = ['Total Renewals'],
            index = ['Patron Type Definition'], 
                       columns= ['Age Range'],
                       aggfunc=[np.mean], 
                       margins=True)
pivot
cmap = sns.cubehelix_palette(start = 1.5, rot = 1.5, as_cmap = True)
plt.subplots(figsize = (30, 20))
sns.heatmap(pivot,linewidths=0.2,square=True )

#Reitred staff of age 20-24 has more than 2000 Renewals
# Out:
# <AxesSubplot:xlabel='None-None-Age Range', ylabel='Patron Type Definition'>

# %%
pivot = pd.pivot_table(df,
            values = ['Total Renewals'],
            index = ['Patron Type Definition'], 
                       columns= ['Circulation Active Month'], 
                       margins=True)
pivot
cmap = sns.cubehelix_palette(start = 1.5, rot = 1.5, as_cmap = True)
plt.subplots(figsize = (30, 20))
sns.heatmap(pivot,linewidths=0.2,square=True )

#The highest value of the total renewals was recevied in the month of july in the patron type of 'Staff'
# Out:
# <AxesSubplot:xlabel='None-Circulation Active Month', ylabel='Patron Type Definition'>

# %%
pivot = pd.pivot_table(df,
            values = ['Total Checkouts'],
            index = ['Patron Type Definition'], 
                       columns= ['Circulation Active Month'], 
                       margins=True)
pivot
cmap = sns.cubehelix_palette(start = 1.5, rot = 1.5, as_cmap = True)
plt.subplots(figsize = (30, 20))
sns.heatmap(pivot,linewidths=0.2,square=True )

#The highest value of the total Checkouts was done in the month of january in the patron type of 'Friends for life'
# Out:
# <AxesSubplot:xlabel='None-Circulation Active Month', ylabel='Patron Type Definition'>
